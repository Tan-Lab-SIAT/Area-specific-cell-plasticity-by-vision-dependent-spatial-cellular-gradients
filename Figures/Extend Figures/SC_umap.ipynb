# %%
import anndata as ad
import numpy as np
import scanpy as sc
import pandas as pd
import openpyxl
import csv
import matplotlib
import scipy.stats as sp
import xgboost as xgb
import pickle
from sklearn.metrics import confusion_matrix, adjusted_rand_score
import matplotlib.pyplot as plt
from matplotlib import gridspec
import scrublet as scr
import seaborn as sns

# %%
N_SC=sc.read_h5ad('G:/single cell data 2025.02.18/SC/N_SC_cluster_use_pca.h5ad')
D_SC=sc.read_h5ad('G:/single cell data 2025.02.18/SC/D_SC_cluster_use_pca.h5ad')

# %%
sc.pl.umap(N_SC, color='Class',legend_loc='on data',save='N_SC_Class.pdf')
# Out:
# WARNING: saving figure to file figures\umapN_SC_Class.pdf
# E:\Python\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(N_SC, color='subclass',legend_loc='on data',legend_fontsize='5',save='N_SC_subclass.pdf')
# Out:
# WARNING: saving figure to file figures\umapN_SC_subclass.pdf
# E:\Python\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(N_SC, color='cluster_use',save='N_SC_cluster_use.pdf')
# Out:
# WARNING: saving figure to file figures\umapN_SC_cluster_use.pdf
# E:\Python\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(D_SC, color='Class',legend_loc='on data',save='D_SC_Class.pdf')
# Out:
# WARNING: saving figure to file figures\umapD_SC_Class.pdf
# E:\Python\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(D_SC, color='subclass',legend_loc='on data',legend_fontsize='5',save='D_SC_subclass.pdf')
# Out:
# WARNING: saving figure to file figures\umapD_SC_subclass.pdf
# E:\Python\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(D_SC, color='cluster_use',save='D_SC_cluster_use.pdf')
# Out:
# WARNING: saving figure to file figures\umapD_SC_cluster_use.pdf
# E:\Python\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
